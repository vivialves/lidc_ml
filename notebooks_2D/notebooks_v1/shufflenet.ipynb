# %% [markdown]
# # LIDC

# %% [markdown]
# # CNN - ShuffleNet

# %%
import os
import pandas as pd
import numpy as np
import time

import torch
import torchvision
import torch.nn as nn
import torch.optim as optim


import matplotlib.pyplot as plt

from torchvision import models
from torchinfo import summary
from torchvision import datasets, transforms
from torch.utils.data import random_split, DataLoader, Dataset
from torchmetrics.classification import MulticlassConfusionMatrix, MulticlassPrecision, MulticlassRecall, MulticlassF1Score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

# %% [markdown]
# ## checking if Gpu were recognized

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
    print("PyTorch is using GPU!")
    print(torch.cuda.get_device_name(0)) #prints the name of the GPU.
else:
    device = torch.device("cpu")
    print("PyTorch is using CPU.")
# Out:
# PyTorch is using GPU!
# NVIDIA GeForce RTX 3050 Ti Laptop GPU

# %% [markdown]
# # Loading Dataset

# %% [markdown]
# ## Training dataset

# %%
path_train = os.path.realpath('data/LIDC_pre/train')

# %%
dataset = datasets.ImageFolder(
    root=path_train, 
    transform=transforms.ToTensor()
)
classes = dataset.classes
print(classes)
# Out:
# ['cancer', 'non-cancer']

# %%
len(dataset)
# Out:
# 148

# %% [markdown]
# ## Test dataset

# %%
path_test = os.path.realpath('data/LIDC_pre/test')

# %%
train_dir = path_train
val_dir = path_test

# %% [markdown]
# # Preprocessing

# %%
IMAGE_SIZE = 256
BATCH_SIZE = 64

# %%
# Define data augmentation for the training dataset
train_transforms = transforms.Compose([
    transforms.RandomResizedCrop(IMAGE_SIZE),   # Random crop and resize
    transforms.RandomHorizontalFlip(p=0.5),     # Random horizontal flip
    transforms.RandomRotation(20),              # Random rotation within ±20 degrees
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.RandomAffine(degrees=0, shear=10, scale=(0.8, 1.2)),  # Shearing
    transforms.ToTensor(),                      # Convert to tensor
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5]) # Normalize
])

# Define validation dataset - no augmentation, only resizing and normalization
test_transforms = transforms.Compose([
    transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])


# split train_dataset and load
train_dataset = torchvision.datasets.ImageFolder(root=train_dir, transform=train_transforms)
test_dataset = torchvision.datasets.ImageFolder(root=val_dir, transform=test_transforms)

train_size = int(0.8 * len(train_dataset))  # 80% for training
val_size = len(train_dataset) - train_size  # Remaining for testing

train_dataset, val_dataset = random_split(train_dataset, [train_size, val_size])

# Define loaders
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=True)


print(f'Training samples: {len(train_dataset)}, , Validation samples: {len(val_dataset)}, Test samples: {len(test_dataset)}')
# Out:
# Training samples: 118, , Validation samples: 30, Test samples: 52

# %% [markdown]
# # Architecture

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
num_classes = 2

model = models.shufflenet_v2_x2_0(weights=None) 
model.fc = nn.Linear(model.fc.in_features, num_classes)
model = model.to(device)

print(model)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
# Out:
# ShuffleNetV2(
#   (conv1): Sequential(
#     (0): Conv2d(3, 24, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (stage2): Sequential(
#     (0): InvertedResidual(
#       (branch1): Sequential(
#         (0): Conv2d(24, 24, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=24, bias=False)
#         (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): Conv2d(24, 122, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(122, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#       )
#       (branch2): Sequential(
#         (0): Conv2d(24, 122, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(122, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(122, 122, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=122, bias=False)
#         (4): BatchNorm2d(122, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(122, 122, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(122, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (1): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(122, 122, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(122, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(122, 122, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=122, bias=False)
#         (4): BatchNorm2d(122, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(122, 122, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(122, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (2): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(122, 122, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(122, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(122, 122, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=122, bias=False)
#         (4): BatchNorm2d(122, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(122, 122, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(122, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (3): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(122, 122, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(122, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(122, 122, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=122, bias=False)
#         (4): BatchNorm2d(122, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(122, 122, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(122, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#   )
#   (stage3): Sequential(
#     (0): InvertedResidual(
#       (branch1): Sequential(
#         (0): Conv2d(244, 244, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=244, bias=False)
#         (1): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): Conv2d(244, 244, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#       )
#       (branch2): Sequential(
#         (0): Conv2d(244, 244, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(244, 244, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=244, bias=False)
#         (4): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(244, 244, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (1): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(244, 244, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(244, 244, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=244, bias=False)
#         (4): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(244, 244, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (2): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(244, 244, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(244, 244, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=244, bias=False)
#         (4): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(244, 244, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (3): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(244, 244, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(244, 244, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=244, bias=False)
#         (4): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(244, 244, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (4): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(244, 244, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(244, 244, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=244, bias=False)
#         (4): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(244, 244, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (5): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(244, 244, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(244, 244, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=244, bias=False)
#         (4): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(244, 244, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (6): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(244, 244, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(244, 244, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=244, bias=False)
#         (4): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(244, 244, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (7): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(244, 244, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(244, 244, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=244, bias=False)
#         (4): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(244, 244, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(244, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#   )
#   (stage4): Sequential(
#     (0): InvertedResidual(
#       (branch1): Sequential(
#         (0): Conv2d(488, 488, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=488, bias=False)
#         (1): BatchNorm2d(488, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): Conv2d(488, 488, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(488, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#       )
#       (branch2): Sequential(
#         (0): Conv2d(488, 488, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(488, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(488, 488, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=488, bias=False)
#         (4): BatchNorm2d(488, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(488, 488, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(488, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (1): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(488, 488, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(488, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(488, 488, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=488, bias=False)
#         (4): BatchNorm2d(488, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(488, 488, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(488, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (2): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(488, 488, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(488, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(488, 488, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=488, bias=False)
#         (4): BatchNorm2d(488, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(488, 488, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(488, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (3): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(488, 488, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(488, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(488, 488, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=488, bias=False)
#         (4): BatchNorm2d(488, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(488, 488, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(488, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#   )
#   (conv5): Sequential(
#     (0): Conv2d(976, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (fc): Linear(in_features=2048, out_features=2, bias=True)
# )

# %%
summary(model, input_size=(BATCH_SIZE, 3, 256, 256))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ShuffleNetV2                             [64, 2]                   --
# ├─Sequential: 1-1                        [64, 24, 128, 128]        --
# │    └─Conv2d: 2-1                       [64, 24, 128, 128]        648
# │    └─BatchNorm2d: 2-2                  [64, 24, 128, 128]        48
# │    └─ReLU: 2-3                         [64, 24, 128, 128]        --
# ├─MaxPool2d: 1-2                         [64, 24, 64, 64]          --
# ├─Sequential: 1-3                        [64, 244, 32, 32]         --
# │    └─InvertedResidual: 2-4             [64, 244, 32, 32]         --
# │    │    └─Sequential: 3-1              [64, 122, 32, 32]         3,436
# │    │    └─Sequential: 3-2              [64, 122, 32, 32]         19,642
# │    └─InvertedResidual: 2-5             [64, 244, 32, 32]         --
# │    │    └─Sequential: 3-3              [64, 122, 32, 32]         31,598
# │    └─InvertedResidual: 2-6             [64, 244, 32, 32]         --
# │    │    └─Sequential: 3-4              [64, 122, 32, 32]         31,598
# │    └─InvertedResidual: 2-7             [64, 244, 32, 32]         --
# │    │    └─Sequential: 3-5              [64, 122, 32, 32]         31,598
# ├─Sequential: 1-4                        [64, 488, 16, 16]         --
# │    └─InvertedResidual: 2-8             [64, 488, 16, 16]         --
# │    │    └─Sequential: 3-6              [64, 244, 16, 16]         62,708
# │    │    └─Sequential: 3-7              [64, 244, 16, 16]         122,732
# │    └─InvertedResidual: 2-9             [64, 488, 16, 16]         --
# │    │    └─Sequential: 3-8              [64, 244, 16, 16]         122,732
# │    └─InvertedResidual: 2-10            [64, 488, 16, 16]         --
# │    │    └─Sequential: 3-9              [64, 244, 16, 16]         122,732
# │    └─InvertedResidual: 2-11            [64, 488, 16, 16]         --
# │    │    └─Sequential: 3-10             [64, 244, 16, 16]         122,732
# │    └─InvertedResidual: 2-12            [64, 488, 16, 16]         --
# │    │    └─Sequential: 3-11             [64, 244, 16, 16]         122,732
# │    └─InvertedResidual: 2-13            [64, 488, 16, 16]         --
# │    │    └─Sequential: 3-12             [64, 244, 16, 16]         122,732
# │    └─InvertedResidual: 2-14            [64, 488, 16, 16]         --
# │    │    └─Sequential: 3-13             [64, 244, 16, 16]         122,732
# │    └─InvertedResidual: 2-15            [64, 488, 16, 16]         --
# │    │    └─Sequential: 3-14             [64, 244, 16, 16]         122,732
# ├─Sequential: 1-5                        [64, 976, 8, 8]           --
# │    └─InvertedResidual: 2-16            [64, 976, 8, 8]           --
# │    │    └─Sequential: 3-15             [64, 488, 8, 8]           244,488
# │    │    └─Sequential: 3-16             [64, 488, 8, 8]           483,608
# │    └─InvertedResidual: 2-17            [64, 976, 8, 8]           --
# │    │    └─Sequential: 3-17             [64, 488, 8, 8]           483,608
# │    └─InvertedResidual: 2-18            [64, 976, 8, 8]           --
# │    │    └─Sequential: 3-18             [64, 488, 8, 8]           483,608
# │    └─InvertedResidual: 2-19            [64, 976, 8, 8]           --
# │    │    └─Sequential: 3-19             [64, 488, 8, 8]           483,608
# ├─Sequential: 1-6                        [64, 2048, 8, 8]          --
# │    └─Conv2d: 2-20                      [64, 2048, 8, 8]          1,998,848
# │    └─BatchNorm2d: 2-21                 [64, 2048, 8, 8]          4,096
# │    └─ReLU: 2-22                        [64, 2048, 8, 8]          --
# ├─Linear: 1-7                            [64, 2]                   4,098
# ==========================================================================================
# Total params: 5,349,094
# Trainable params: 5,349,094
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 48.59
# ==========================================================================================
# Input size (MB): 50.33
# Forward/backward pass size (MB): 5007.48
# Params size (MB): 21.40
# Estimated Total Size (MB): 5079.20
# ==========================================================================================

# %% [markdown]
# # Trainning

# %%
def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs):
    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []

    # Metrics
    confusion_matrix = MulticlassConfusionMatrix(num_classes=2)
    precision = MulticlassPrecision(num_classes=10, average='macro')
    recall = MulticlassRecall(num_classes=10, average='macro')
    f1_score = MulticlassF1Score(num_classes=10, average='macro')

    for epoch in range(num_epochs):
        # Training
        model.train()
        train_loss = 0.0
        correct_train = 0
        total_train = 0

        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            # Clear gradients
            optimizer.zero_grad()

            # feed foward
            outputs = model(inputs)
            
            # Compute loss using cross entropy
            loss = criterion(outputs, labels)

            # backpropagation
            loss.backward()

            # Update weights
            optimizer.step()

            # Update results
            train_loss += loss.item()
            _, preds = torch.max(outputs, 1)
            total_train += labels.size(0)
            correct_train += (preds == labels).sum().item()

        train_losses.append(train_loss / len(train_loader))
        train_accuracies.append(100 * correct_train / total_train)

        # Evaluation part to print metrics for each epoch
        model.eval()
        val_loss = 0.0
        correct_val = 0
        total_val = 0

        all_preds = []
        all_labels = []

        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item()

                _, preds = torch.max(outputs, 1)
                total_val += labels.size(0)
                correct_val += (preds == labels).sum().item()

                # For metrics
                all_preds.append(preds.cpu())
                all_labels.append(labels.cpu())

        val_losses.append(val_loss / len(val_loader))
        val_accuracies.append(100 * correct_val / total_val)

        
        all_preds = torch.cat(all_preds)
        all_labels = torch.cat(all_labels)

        
        precision_value = precision(all_preds, all_labels)
        recall_value = recall(all_preds, all_labels)
        f1_value = f1_score(all_preds, all_labels)
        conf_matrix = confusion_matrix(all_preds, all_labels)

        
        print(f"Epoch {epoch + 1}/{num_epochs}")
        print(f"Train Loss: {train_losses[-1]:.4f} | Train Acc: {train_accuracies[-1]:.2f}%")
        print(f"Val Loss: {val_losses[-1]:.4f} | Val Acc: {val_accuracies[-1]:.2f}%")
        print(f"Precision: {precision_value:.4f} | Recall: {recall_value:.4f} | F1 Score: {f1_value:.4f}\n")

    return train_losses, val_losses, train_accuracies, val_accuracies, conf_matrix

# %%
t1 = time.time()
print(f"Using device: {device}")
train_losses, val_losses, train_accuracies, val_accuracies, conf_matrix = train_model(
    model, train_loader, val_loader, criterion, optimizer, num_epochs=50)

print("######## Training Finished in {} seconds ###########".format(time.time()-t1))
# Out:
# Using device: cuda
# Epoch 1/50
# Train Loss: 0.9959 | Train Acc: 64.41%
# Val Loss: 0.5584 | Val Acc: 86.67%
# Precision: 0.4333 | Recall: 0.5000 | F1 Score: 0.4643
#
# Epoch 2/50
# Train Loss: 0.7706 | Train Acc: 80.51%
# Val Loss: 0.4946 | Val Acc: 86.67%
# Precision: 0.4333 | Recall: 0.5000 | F1 Score: 0.4643
#
# Epoch 3/50
# Train Loss: 0.7293 | Train Acc: 81.36%
# Val Loss: 0.4729 | Val Acc: 86.67%
# Precision: 0.4333 | Recall: 0.5000 | F1 Score: 0.4643
#
# Epoch 4/50
# Train Loss: 0.7940 | Train Acc: 77.97%
# Val Loss: 0.4703 | Val Acc: 86.67%
# Precision: 0.4333 | Recall: 0.5000 | F1 Score: 0.4643
#
# Epoch 5/50
# Train Loss: 0.5103 | Train Acc: 78.81%
# Val Loss: 0.5097 | Val Acc: 86.67%
# Precision: 0.4333 | Recall: 0.5000 | F1 Score: 0.4643
#
# Epoch 6/50
# Train Loss: 0.5565 | Train Acc: 72.88%
# Val Loss: 0.5392 | Val Acc: 86.67%
# Precision: 0.4333 | Recall: 0.5000 | F1 Score: 0.4643
#
# Epoch 7/50
# Train Loss: 0.5121 | Train Acc: 77.97%
# Val Loss: 0.5140 | Val Acc: 86.67%
# Precision: 0.4333 | Recall: 0.5000 | F1 Score: 0.4643
#
# Epoch 8/50
# Train Loss: 0.5137 | Train Acc: 78.81%
# Val Loss: 0.4395 | Val Acc: 86.67%
# Precision: 0.4333 | Recall: 0.5000 | F1 Score: 0.4643
#
# Epoch 9/50
# Train Loss: 0.5639 | Train Acc: 78.81%
# Val Loss: 0.4641 | Val Acc: 86.67%
# Precision: 0.4333 | Recall: 0.5000 | F1 Score: 0.4643
#
# Epoch 10/50
# Train Loss: 0.5549 | Train Acc: 81.36%
# Val Loss: 0.6284 | Val Acc: 86.67%
# Precision: 0.4333 | Recall: 0.5000 | F1 Score: 0.4643
#
# Epoch 11/50
# Train Loss: 0.5318 | Train Acc: 79.66%
# Val Loss: 0.6648 | Val Acc: 76.67%
# Precision: 0.4259 | Recall: 0.4423 | F1 Score: 0.4340
#
# Epoch 12/50
# Train Loss: 0.5073 | Train Acc: 77.12%
# Val Loss: 0.8593 | Val Acc: 13.33%
# Precision: 0.0667 | Recall: 0.5000 | F1 Score: 0.1176
#
# Epoch 13/50
# Train Loss: 0.5138 | Train Acc: 81.36%
# Val Loss: 1.4598 | Val Acc: 13.33%
# Precision: 0.0667 | Recall: 0.5000 | F1 Score: 0.1176
#
# Epoch 14/50
# Train Loss: 0.5219 | Train Acc: 79.66%
# Val Loss: 0.7277 | Val Acc: 30.00%
# Precision: 0.4938 | Recall: 0.4904 | F1 Score: 0.2929
#
# Epoch 15/50
# Train Loss: 0.5443 | Train Acc: 80.51%
# Val Loss: 0.5090 | Val Acc: 86.67%
# Precision: 0.4333 | Recall: 0.5000 | F1 Score: 0.4643
#
# Epoch 16/50
# Train Loss: 0.5071 | Train Acc: 80.51%
# Val Loss: 0.5004 | Val Acc: 86.67%
# Precision: 0.4333 | Recall: 0.5000 | F1 Score: 0.4643
#
# Epoch 17/50
# Train Loss: 0.5052 | Train Acc: 80.51%
# Val Loss: 0.4263 | Val Acc: 86.67%
# Precision: 0.4333 | Recall: 0.5000 | F1 Score: 0.4643
#
# Epoch 18/50
# Train Loss: 0.5310 | Train Acc: 79.66%
# Val Loss: 0.5263 | Val Acc: 86.67%
# Precision: 0.4333 | Recall: 0.5000 | F1 Score: 0.4643
#
# Epoch 19/50
# Train Loss: 0.5093 | Train Acc: 78.81%
# Val Loss: 0.6973 | Val Acc: 46.67%
# Precision: 0.5417 | Recall: 0.5865 | F1 Score: 0.4258
#
# Epoch 20/50
# Train Loss: 0.5068 | Train Acc: 78.81%
# Val Loss: 0.4788 | Val Acc: 86.67%
# Precision: 0.4333 | Recall: 0.5000 | F1 Score: 0.4643
#
# Epoch 21/50
# Train Loss: 0.4869 | Train Acc: 81.36%
# Val Loss: 0.3999 | Val Acc: 86.67%
# Precision: 0.4333 | Recall: 0.5000 | F1 Score: 0.4643
#
# Epoch 22/50
# Train Loss: 0.4731 | Train Acc: 82.20%
# Val Loss: 0.4142 | Val Acc: 86.67%
# Precision: 0.4333 | Recall: 0.5000 | F1 Score: 0.4643
#
# Epoch 23/50
# Train Loss: 0.4935 | Train Acc: 79.66%
# Val Loss: 0.4692 | Val Acc: 86.67%
# Precision: 0.4333 | Recall: 0.5000 | F1 Score: 0.4643
#
# Epoch 24/50
# Train Loss: 0.5102 | Train Acc: 81.36%
# Val Loss: 0.4546 | Val Acc: 86.67%
# Precision: 0.4333 | Recall: 0.5000 | F1 Score: 0.4643
#
# Epoch 25/50
# Train Loss: 0.4594 | Train Acc: 82.20%
# Val Loss: 0.4182 | Val Acc: 86.67%
# Precision: 0.4333 | Recall: 0.5000 | F1 Score: 0.4643
#
# Epoch 26/50
# Train Loss: 0.4714 | Train Acc: 80.51%
# Val Loss: 0.3975 | Val Acc: 86.67%
# Precision: 0.4333 | Recall: 0.5000 | F1 Score: 0.4643
#
# Epoch 27/50
# Train Loss: 0.4989 | Train Acc: 80.51%
# Val Loss: 0.3732 | Val Acc: 86.67%
# Precision: 0.4333 | Recall: 0.5000 | F1 Score: 0.4643
#
# Epoch 28/50
# Train Loss: 0.4764 | Train Acc: 80.51%
# Val Loss: 0.4007 | Val Acc: 86.67%
# Precision: 0.4333 | Recall: 0.5000 | F1 Score: 0.4643
#
# Epoch 29/50
# Train Loss: 0.4670 | Train Acc: 81.36%
# Val Loss: 0.4389 | Val Acc: 80.00%
# Precision: 0.4286 | Recall: 0.4615 | F1 Score: 0.4444
#
# Epoch 30/50
# Train Loss: 0.4687 | Train Acc: 82.20%
# Val Loss: 0.4428 | Val Acc: 83.33%
# Precision: 0.4310 | Recall: 0.4808 | F1 Score: 0.4545
#
# Epoch 31/50
# Train Loss: 0.4702 | Train Acc: 79.66%
# Val Loss: 0.4277 | Val Acc: 86.67%
# Precision: 0.4333 | Recall: 0.5000 | F1 Score: 0.4643
#
# Epoch 32/50
# Train Loss: 0.4468 | Train Acc: 80.51%
# Val Loss: 0.4555 | Val Acc: 86.67%
# Precision: 0.4333 | Recall: 0.5000 | F1 Score: 0.4643
#
# Epoch 33/50
# Train Loss: 0.4884 | Train Acc: 79.66%
# Val Loss: 0.4321 | Val Acc: 83.33%
# Precision: 0.4310 | Recall: 0.4808 | F1 Score: 0.4545
#
# Epoch 34/50
# Train Loss: 0.4933 | Train Acc: 80.51%
# Val Loss: 0.4576 | Val Acc: 86.67%
# Precision: 0.4333 | Recall: 0.5000 | F1 Score: 0.4643
#
# Epoch 35/50
# Train Loss: 0.4954 | Train Acc: 78.81%
# Val Loss: 0.4467 | Val Acc: 86.67%
# Precision: 0.4333 | Recall: 0.5000 | F1 Score: 0.4643
#
# Epoch 36/50
# Train Loss: 0.4560 | Train Acc: 80.51%
# Val Loss: 0.4387 | Val Acc: 83.33%
# Precision: 0.4310 | Recall: 0.4808 | F1 Score: 0.4545
#
# Epoch 37/50
# Train Loss: 0.4829 | Train Acc: 79.66%
# Val Loss: 0.4457 | Val Acc: 83.33%
# Precision: 0.4310 | Recall: 0.4808 | F1 Score: 0.4545
#
# Epoch 38/50
# Train Loss: 0.4565 | Train Acc: 80.51%
# Val Loss: 0.4604 | Val Acc: 80.00%
# Precision: 0.4286 | Recall: 0.4615 | F1 Score: 0.4444
#
# Epoch 39/50
# Train Loss: 0.4615 | Train Acc: 83.05%
# Val Loss: 0.4707 | Val Acc: 80.00%
# Precision: 0.4286 | Recall: 0.4615 | F1 Score: 0.4444
#
# Epoch 40/50
# Train Loss: 0.4531 | Train Acc: 83.90%
# Val Loss: 0.5516 | Val Acc: 76.67%
# Precision: 0.4259 | Recall: 0.4423 | F1 Score: 0.4340
#
# Epoch 41/50
# Train Loss: 0.4820 | Train Acc: 80.51%
# Val Loss: 0.4338 | Val Acc: 86.67%
# Precision: 0.4333 | Recall: 0.5000 | F1 Score: 0.4643
#
# Epoch 42/50
# Train Loss: 0.4560 | Train Acc: 82.20%
# Val Loss: 0.4253 | Val Acc: 83.33%
# Precision: 0.4310 | Recall: 0.4808 | F1 Score: 0.4545
#
# Epoch 43/50
# Train Loss: 0.4624 | Train Acc: 81.36%
# Val Loss: 0.3928 | Val Acc: 86.67%
# Precision: 0.4333 | Recall: 0.5000 | F1 Score: 0.4643
#
# Epoch 44/50
# Train Loss: 0.4983 | Train Acc: 79.66%
# Val Loss: 0.3827 | Val Acc: 86.67%
# Precision: 0.4333 | Recall: 0.5000 | F1 Score: 0.4643
#
# Epoch 45/50
# Train Loss: 0.4901 | Train Acc: 81.36%
# Val Loss: 0.4394 | Val Acc: 86.67%
# Precision: 0.4333 | Recall: 0.5000 | F1 Score: 0.4643
#
# Epoch 46/50
# Train Loss: 0.4624 | Train Acc: 80.51%
# Val Loss: 0.4046 | Val Acc: 86.67%
# Precision: 0.4333 | Recall: 0.5000 | F1 Score: 0.4643
#
# Epoch 47/50
# Train Loss: 0.4827 | Train Acc: 81.36%
# Val Loss: 0.4439 | Val Acc: 83.33%
# Precision: 0.4310 | Recall: 0.4808 | F1 Score: 0.4545
#
# Epoch 48/50
# Train Loss: 0.4722 | Train Acc: 81.36%
# Val Loss: 0.4658 | Val Acc: 86.67%
# Precision: 0.4333 | Recall: 0.5000 | F1 Score: 0.4643
#
# Epoch 49/50
# Train Loss: 0.4662 | Train Acc: 81.36%
# Val Loss: 0.4142 | Val Acc: 83.33%
# Precision: 0.4310 | Recall: 0.4808 | F1 Score: 0.4545
#
# Epoch 50/50
# Train Loss: 0.4648 | Train Acc: 81.36%
# Val Loss: 0.4634 | Val Acc: 83.33%
# Precision: 0.4310 | Recall: 0.4808 | F1 Score: 0.4545
#
# ######## Training Finished in 88.85484504699707 seconds ###########

# %% [markdown]
# # Evaluating

# %%
model.eval() 

with torch.no_grad(): 
    correct = 0
    total = 0
    for data in test_loader:
        images, labels = data[0].to(device), data[1].to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
    print(f'Test Accuracy of the model on the {total} test images: {(correct / total) * 100:.2f}%')
# Out:
# Test Accuracy of the model on the 52 test images: 78.85%

# %%
def plot_training(train_losses, val_losses, train_accuracies, val_accuracies):
    epochs = range(1, len(train_losses) + 1)

    plt.figure(figsize=(12, 5))
    
    # Plot loss
    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, label='Train Loss')
    plt.plot(epochs, val_losses, label='Val Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss')
    plt.legend()

    # Plot accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_accuracies, label='Train Accuracy')
    plt.plot(epochs, val_accuracies, label='Val Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy (%)')
    plt.title('Training and Validation Accuracy')
    plt.legend()

    plt.show()

plot_training(train_losses, val_losses, train_accuracies, val_accuracies)

# %%
cm = conf_matrix.cpu().numpy()
disp = ConfusionMatrixDisplay(cm, display_labels=classes,)
disp.plot()

# %% [markdown]
# # Metrics

# %%
precision = MulticlassPrecision(num_classes=num_classes, average=None)
recall = MulticlassRecall(num_classes=num_classes, average=None)
f1_score = MulticlassF1Score(num_classes=num_classes, average=None)


all_preds = []
all_labels = []

model.eval()
with torch.no_grad():
    for inputs, labels in val_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        all_preds.append(preds.cpu())
        all_labels.append(labels.cpu())


all_preds = torch.cat(all_preds)
all_labels = torch.cat(all_labels)


per_class_precision = precision(all_preds, all_labels)
per_class_recall = recall(all_preds, all_labels)
per_class_f1 = f1_score(all_preds, all_labels)


for i, name in enumerate(classes):
    print(f"Class {i}-{name}: Precision: {per_class_precision[i]:.2f}, Recall: {per_class_recall[i]:.2f}, F1-Score: {per_class_f1[i]:.2f}")
# Out:
# Class 0-cancer: Precision: 0.00, Recall: 0.00, F1-Score: 0.00
# Class 1-non-cancer: Precision: 0.86, Recall: 0.92, F1-Score: 0.89

# %% [markdown]
# # Save Model

# %%
# torch.save(model.state_dict(), '/home/viviane/projects/breast-cancer-v2/models/model_alexnet.pt')

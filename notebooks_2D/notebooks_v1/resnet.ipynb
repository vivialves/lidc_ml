# %% [markdown]
# # LIDC

# %% [markdown]
# # CNN - ResNet

# %%
import os
import pandas as pd
import numpy as np
import time

import torch
import torchvision
import torch.nn as nn
import torch.optim as optim


import matplotlib.pyplot as plt

from torchvision import models
from torchinfo import summary
from torchvision import datasets, transforms
from torch.utils.data import random_split, DataLoader, Dataset
from torchmetrics.classification import MulticlassConfusionMatrix, MulticlassPrecision, MulticlassRecall, MulticlassF1Score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

# %% [markdown]
# ## checking if Gpu were recognized

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
    print("PyTorch is using GPU!")
    print(torch.cuda.get_device_name(0)) #prints the name of the GPU.
else:
    device = torch.device("cpu")
    print("PyTorch is using CPU.")
# Out:
# PyTorch is using GPU!
# NVIDIA GeForce RTX 3050 Ti Laptop GPU

# %% [markdown]
# # Loading Dataset

# %% [markdown]
# ## Training dataset

# %%
path_train = os.path.realpath('data/LIDC_pre/train')

# %%
dataset = datasets.ImageFolder(
    root=path_train, 
    transform=transforms.ToTensor()
)
classes = dataset.classes
print(classes)
# Out:
# ['cancer', 'non-cancer']

# %%
len(dataset)
# Out:
# 148

# %% [markdown]
# ## Test dataset

# %%
path_test = os.path.realpath('data/LIDC_pre/test')

# %%
train_dir = path_train
val_dir = path_test

# %% [markdown]
# # Preprocessing

# %%
IMAGE_SIZE = 256
BATCH_SIZE = 32

# %%
# Define data augmentation for the training dataset
train_transforms = transforms.Compose([
    transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)),
    transforms.ToTensor(),                      
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5]) # Normalization
])

# Define validation dataset - no augmentation, only resizing and normalization
test_transforms = transforms.Compose([
    transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])


# split train_dataset and load
train_dataset = torchvision.datasets.ImageFolder(root=train_dir, transform=train_transforms)
test_dataset = torchvision.datasets.ImageFolder(root=val_dir, transform=test_transforms)

train_size = int(0.8 * len(train_dataset))  # 80% for training
val_size = len(train_dataset) - train_size  # Remaining for testing

train_dataset, val_dataset = random_split(train_dataset, [train_size, val_size])

# Define loaders
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=True)


print(f'Training samples: {len(train_dataset)}, , Validation samples: {len(val_dataset)}, Test samples: {len(test_dataset)}')
# Out:
# Training samples: 118, , Validation samples: 30, Test samples: 52

# %% [markdown]
# # Architecture

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
num_classes = 2

model = models.resnet50(weights=None) 
model.fc = nn.Linear(model.fc.in_features, num_classes)
model = model.to(device)

print(model)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=2, bias=True)
# )

# %%
summary(model, input_size=(BATCH_SIZE, 3, 256, 256))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ResNet                                   [32, 2]                   --
# ├─Conv2d: 1-1                            [32, 64, 128, 128]        9,408
# ├─BatchNorm2d: 1-2                       [32, 64, 128, 128]        128
# ├─ReLU: 1-3                              [32, 64, 128, 128]        --
# ├─MaxPool2d: 1-4                         [32, 64, 64, 64]          --
# ├─Sequential: 1-5                        [32, 256, 64, 64]         --
# │    └─Bottleneck: 2-1                   [32, 256, 64, 64]         --
# │    │    └─Conv2d: 3-1                  [32, 64, 64, 64]          4,096
# │    │    └─BatchNorm2d: 3-2             [32, 64, 64, 64]          128
# │    │    └─ReLU: 3-3                    [32, 64, 64, 64]          --
# │    │    └─Conv2d: 3-4                  [32, 64, 64, 64]          36,864
# │    │    └─BatchNorm2d: 3-5             [32, 64, 64, 64]          128
# │    │    └─ReLU: 3-6                    [32, 64, 64, 64]          --
# │    │    └─Conv2d: 3-7                  [32, 256, 64, 64]         16,384
# │    │    └─BatchNorm2d: 3-8             [32, 256, 64, 64]         512
# │    │    └─Sequential: 3-9              [32, 256, 64, 64]         16,896
# │    │    └─ReLU: 3-10                   [32, 256, 64, 64]         --
# │    └─Bottleneck: 2-2                   [32, 256, 64, 64]         --
# │    │    └─Conv2d: 3-11                 [32, 64, 64, 64]          16,384
# │    │    └─BatchNorm2d: 3-12            [32, 64, 64, 64]          128
# │    │    └─ReLU: 3-13                   [32, 64, 64, 64]          --
# │    │    └─Conv2d: 3-14                 [32, 64, 64, 64]          36,864
# │    │    └─BatchNorm2d: 3-15            [32, 64, 64, 64]          128
# │    │    └─ReLU: 3-16                   [32, 64, 64, 64]          --
# │    │    └─Conv2d: 3-17                 [32, 256, 64, 64]         16,384
# │    │    └─BatchNorm2d: 3-18            [32, 256, 64, 64]         512
# │    │    └─ReLU: 3-19                   [32, 256, 64, 64]         --
# │    └─Bottleneck: 2-3                   [32, 256, 64, 64]         --
# │    │    └─Conv2d: 3-20                 [32, 64, 64, 64]          16,384
# │    │    └─BatchNorm2d: 3-21            [32, 64, 64, 64]          128
# │    │    └─ReLU: 3-22                   [32, 64, 64, 64]          --
# │    │    └─Conv2d: 3-23                 [32, 64, 64, 64]          36,864
# │    │    └─BatchNorm2d: 3-24            [32, 64, 64, 64]          128
# │    │    └─ReLU: 3-25                   [32, 64, 64, 64]          --
# │    │    └─Conv2d: 3-26                 [32, 256, 64, 64]         16,384
# │    │    └─BatchNorm2d: 3-27            [32, 256, 64, 64]         512
# │    │    └─ReLU: 3-28                   [32, 256, 64, 64]         --
# ├─Sequential: 1-6                        [32, 512, 32, 32]         --
# │    └─Bottleneck: 2-4                   [32, 512, 32, 32]         --
# │    │    └─Conv2d: 3-29                 [32, 128, 64, 64]         32,768
# │    │    └─BatchNorm2d: 3-30            [32, 128, 64, 64]         256
# │    │    └─ReLU: 3-31                   [32, 128, 64, 64]         --
# │    │    └─Conv2d: 3-32                 [32, 128, 32, 32]         147,456
# │    │    └─BatchNorm2d: 3-33            [32, 128, 32, 32]         256
# │    │    └─ReLU: 3-34                   [32, 128, 32, 32]         --
# │    │    └─Conv2d: 3-35                 [32, 512, 32, 32]         65,536
# │    │    └─BatchNorm2d: 3-36            [32, 512, 32, 32]         1,024
# │    │    └─Sequential: 3-37             [32, 512, 32, 32]         132,096
# │    │    └─ReLU: 3-38                   [32, 512, 32, 32]         --
# │    └─Bottleneck: 2-5                   [32, 512, 32, 32]         --
# │    │    └─Conv2d: 3-39                 [32, 128, 32, 32]         65,536
# │    │    └─BatchNorm2d: 3-40            [32, 128, 32, 32]         256
# │    │    └─ReLU: 3-41                   [32, 128, 32, 32]         --
# │    │    └─Conv2d: 3-42                 [32, 128, 32, 32]         147,456
# │    │    └─BatchNorm2d: 3-43            [32, 128, 32, 32]         256
# │    │    └─ReLU: 3-44                   [32, 128, 32, 32]         --
# │    │    └─Conv2d: 3-45                 [32, 512, 32, 32]         65,536
# │    │    └─BatchNorm2d: 3-46            [32, 512, 32, 32]         1,024
# │    │    └─ReLU: 3-47                   [32, 512, 32, 32]         --
# │    └─Bottleneck: 2-6                   [32, 512, 32, 32]         --
# │    │    └─Conv2d: 3-48                 [32, 128, 32, 32]         65,536
# │    │    └─BatchNorm2d: 3-49            [32, 128, 32, 32]         256
# │    │    └─ReLU: 3-50                   [32, 128, 32, 32]         --
# │    │    └─Conv2d: 3-51                 [32, 128, 32, 32]         147,456
# │    │    └─BatchNorm2d: 3-52            [32, 128, 32, 32]         256
# │    │    └─ReLU: 3-53                   [32, 128, 32, 32]         --
# │    │    └─Conv2d: 3-54                 [32, 512, 32, 32]         65,536
# │    │    └─BatchNorm2d: 3-55            [32, 512, 32, 32]         1,024
# │    │    └─ReLU: 3-56                   [32, 512, 32, 32]         --
# │    └─Bottleneck: 2-7                   [32, 512, 32, 32]         --
# │    │    └─Conv2d: 3-57                 [32, 128, 32, 32]         65,536
# │    │    └─BatchNorm2d: 3-58            [32, 128, 32, 32]         256
# │    │    └─ReLU: 3-59                   [32, 128, 32, 32]         --
# │    │    └─Conv2d: 3-60                 [32, 128, 32, 32]         147,456
# │    │    └─BatchNorm2d: 3-61            [32, 128, 32, 32]         256
# │    │    └─ReLU: 3-62                   [32, 128, 32, 32]         --
# │    │    └─Conv2d: 3-63                 [32, 512, 32, 32]         65,536
# │    │    └─BatchNorm2d: 3-64            [32, 512, 32, 32]         1,024
# │    │    └─ReLU: 3-65                   [32, 512, 32, 32]         --
# ├─Sequential: 1-7                        [32, 1024, 16, 16]        --
# │    └─Bottleneck: 2-8                   [32, 1024, 16, 16]        --
# │    │    └─Conv2d: 3-66                 [32, 256, 32, 32]         131,072
# │    │    └─BatchNorm2d: 3-67            [32, 256, 32, 32]         512
# │    │    └─ReLU: 3-68                   [32, 256, 32, 32]         --
# │    │    └─Conv2d: 3-69                 [32, 256, 16, 16]         589,824
# │    │    └─BatchNorm2d: 3-70            [32, 256, 16, 16]         512
# │    │    └─ReLU: 3-71                   [32, 256, 16, 16]         --
# │    │    └─Conv2d: 3-72                 [32, 1024, 16, 16]        262,144
# │    │    └─BatchNorm2d: 3-73            [32, 1024, 16, 16]        2,048
# │    │    └─Sequential: 3-74             [32, 1024, 16, 16]        526,336
# │    │    └─ReLU: 3-75                   [32, 1024, 16, 16]        --
# │    └─Bottleneck: 2-9                   [32, 1024, 16, 16]        --
# │    │    └─Conv2d: 3-76                 [32, 256, 16, 16]         262,144
# │    │    └─BatchNorm2d: 3-77            [32, 256, 16, 16]         512
# │    │    └─ReLU: 3-78                   [32, 256, 16, 16]         --
# │    │    └─Conv2d: 3-79                 [32, 256, 16, 16]         589,824
# │    │    └─BatchNorm2d: 3-80            [32, 256, 16, 16]         512
# │    │    └─ReLU: 3-81                   [32, 256, 16, 16]         --
# │    │    └─Conv2d: 3-82                 [32, 1024, 16, 16]        262,144
# │    │    └─BatchNorm2d: 3-83            [32, 1024, 16, 16]        2,048
# │    │    └─ReLU: 3-84                   [32, 1024, 16, 16]        --
# │    └─Bottleneck: 2-10                  [32, 1024, 16, 16]        --
# │    │    └─Conv2d: 3-85                 [32, 256, 16, 16]         262,144
# │    │    └─BatchNorm2d: 3-86            [32, 256, 16, 16]         512
# │    │    └─ReLU: 3-87                   [32, 256, 16, 16]         --
# │    │    └─Conv2d: 3-88                 [32, 256, 16, 16]         589,824
# │    │    └─BatchNorm2d: 3-89            [32, 256, 16, 16]         512
# │    │    └─ReLU: 3-90                   [32, 256, 16, 16]         --
# │    │    └─Conv2d: 3-91                 [32, 1024, 16, 16]        262,144
# │    │    └─BatchNorm2d: 3-92            [32, 1024, 16, 16]        2,048
# │    │    └─ReLU: 3-93                   [32, 1024, 16, 16]        --
# │    └─Bottleneck: 2-11                  [32, 1024, 16, 16]        --
# │    │    └─Conv2d: 3-94                 [32, 256, 16, 16]         262,144
# │    │    └─BatchNorm2d: 3-95            [32, 256, 16, 16]         512
# │    │    └─ReLU: 3-96                   [32, 256, 16, 16]         --
# │    │    └─Conv2d: 3-97                 [32, 256, 16, 16]         589,824
# │    │    └─BatchNorm2d: 3-98            [32, 256, 16, 16]         512
# │    │    └─ReLU: 3-99                   [32, 256, 16, 16]         --
# │    │    └─Conv2d: 3-100                [32, 1024, 16, 16]        262,144
# │    │    └─BatchNorm2d: 3-101           [32, 1024, 16, 16]        2,048
# │    │    └─ReLU: 3-102                  [32, 1024, 16, 16]        --
# │    └─Bottleneck: 2-12                  [32, 1024, 16, 16]        --
# │    │    └─Conv2d: 3-103                [32, 256, 16, 16]         262,144
# │    │    └─BatchNorm2d: 3-104           [32, 256, 16, 16]         512
# │    │    └─ReLU: 3-105                  [32, 256, 16, 16]         --
# │    │    └─Conv2d: 3-106                [32, 256, 16, 16]         589,824
# │    │    └─BatchNorm2d: 3-107           [32, 256, 16, 16]         512
# │    │    └─ReLU: 3-108                  [32, 256, 16, 16]         --
# │    │    └─Conv2d: 3-109                [32, 1024, 16, 16]        262,144
# │    │    └─BatchNorm2d: 3-110           [32, 1024, 16, 16]        2,048
# │    │    └─ReLU: 3-111                  [32, 1024, 16, 16]        --
# │    └─Bottleneck: 2-13                  [32, 1024, 16, 16]        --
# │    │    └─Conv2d: 3-112                [32, 256, 16, 16]         262,144
# │    │    └─BatchNorm2d: 3-113           [32, 256, 16, 16]         512
# │    │    └─ReLU: 3-114                  [32, 256, 16, 16]         --
# │    │    └─Conv2d: 3-115                [32, 256, 16, 16]         589,824
# │    │    └─BatchNorm2d: 3-116           [32, 256, 16, 16]         512
# │    │    └─ReLU: 3-117                  [32, 256, 16, 16]         --
# │    │    └─Conv2d: 3-118                [32, 1024, 16, 16]        262,144
# │    │    └─BatchNorm2d: 3-119           [32, 1024, 16, 16]        2,048
# │    │    └─ReLU: 3-120                  [32, 1024, 16, 16]        --
# ├─Sequential: 1-8                        [32, 2048, 8, 8]          --
# │    └─Bottleneck: 2-14                  [32, 2048, 8, 8]          --
# │    │    └─Conv2d: 3-121                [32, 512, 16, 16]         524,288
# │    │    └─BatchNorm2d: 3-122           [32, 512, 16, 16]         1,024
# │    │    └─ReLU: 3-123                  [32, 512, 16, 16]         --
# │    │    └─Conv2d: 3-124                [32, 512, 8, 8]           2,359,296
# │    │    └─BatchNorm2d: 3-125           [32, 512, 8, 8]           1,024
# │    │    └─ReLU: 3-126                  [32, 512, 8, 8]           --
# │    │    └─Conv2d: 3-127                [32, 2048, 8, 8]          1,048,576
# │    │    └─BatchNorm2d: 3-128           [32, 2048, 8, 8]          4,096
# │    │    └─Sequential: 3-129            [32, 2048, 8, 8]          2,101,248
# │    │    └─ReLU: 3-130                  [32, 2048, 8, 8]          --
# │    └─Bottleneck: 2-15                  [32, 2048, 8, 8]          --
# │    │    └─Conv2d: 3-131                [32, 512, 8, 8]           1,048,576
# │    │    └─BatchNorm2d: 3-132           [32, 512, 8, 8]           1,024
# │    │    └─ReLU: 3-133                  [32, 512, 8, 8]           --
# │    │    └─Conv2d: 3-134                [32, 512, 8, 8]           2,359,296
# │    │    └─BatchNorm2d: 3-135           [32, 512, 8, 8]           1,024
# │    │    └─ReLU: 3-136                  [32, 512, 8, 8]           --
# │    │    └─Conv2d: 3-137                [32, 2048, 8, 8]          1,048,576
# │    │    └─BatchNorm2d: 3-138           [32, 2048, 8, 8]          4,096
# │    │    └─ReLU: 3-139                  [32, 2048, 8, 8]          --
# │    └─Bottleneck: 2-16                  [32, 2048, 8, 8]          --
# │    │    └─Conv2d: 3-140                [32, 512, 8, 8]           1,048,576
# │    │    └─BatchNorm2d: 3-141           [32, 512, 8, 8]           1,024
# │    │    └─ReLU: 3-142                  [32, 512, 8, 8]           --
# │    │    └─Conv2d: 3-143                [32, 512, 8, 8]           2,359,296
# │    │    └─BatchNorm2d: 3-144           [32, 512, 8, 8]           1,024
# │    │    └─ReLU: 3-145                  [32, 512, 8, 8]           --
# │    │    └─Conv2d: 3-146                [32, 2048, 8, 8]          1,048,576
# │    │    └─BatchNorm2d: 3-147           [32, 2048, 8, 8]          4,096
# │    │    └─ReLU: 3-148                  [32, 2048, 8, 8]          --
# ├─AdaptiveAvgPool2d: 1-9                 [32, 2048, 1, 1]          --
# ├─Linear: 1-10                           [32, 2]                   4,098
# ==========================================================================================
# Total params: 23,512,130
# Trainable params: 23,512,130
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 170.83
# ==========================================================================================
# Input size (MB): 25.17
# Forward/backward pass size (MB): 7432.31
# Params size (MB): 94.05
# Estimated Total Size (MB): 7551.52
# ==========================================================================================

# %% [markdown]
# # Trainning

# %%
def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs):
    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []

    # Metrics
    confusion_matrix = MulticlassConfusionMatrix(num_classes=2)
    precision = MulticlassPrecision(num_classes=10, average='macro')
    recall = MulticlassRecall(num_classes=10, average='macro')
    f1_score = MulticlassF1Score(num_classes=10, average='macro')

    for epoch in range(num_epochs):
        # Training
        model.train()
        train_loss = 0.0
        correct_train = 0
        total_train = 0

        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            # Clear gradients
            optimizer.zero_grad()

            # feed foward
            outputs = model(inputs)
            
            # Compute loss using cross entropy
            loss = criterion(outputs, labels)

            # backpropagation
            loss.backward()

            # Update weights
            optimizer.step()

            # Update results
            train_loss += loss.item()
            _, preds = torch.max(outputs, 1)
            total_train += labels.size(0)
            correct_train += (preds == labels).sum().item()

        train_losses.append(train_loss / len(train_loader))
        train_accuracies.append(100 * correct_train / total_train)

        # Evaluation part to print metrics for each epoch
        model.eval()
        val_loss = 0.0
        correct_val = 0
        total_val = 0

        all_preds = []
        all_labels = []

        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item()

                _, preds = torch.max(outputs, 1)
                total_val += labels.size(0)
                correct_val += (preds == labels).sum().item()

                # For metrics
                all_preds.append(preds.cpu())
                all_labels.append(labels.cpu())

        val_losses.append(val_loss / len(val_loader))
        val_accuracies.append(100 * correct_val / total_val)

        
        all_preds = torch.cat(all_preds)
        all_labels = torch.cat(all_labels)

        
        precision_value = precision(all_preds, all_labels)
        recall_value = recall(all_preds, all_labels)
        f1_value = f1_score(all_preds, all_labels)
        conf_matrix = confusion_matrix(all_preds, all_labels)

        
        print(f"Epoch {epoch + 1}/{num_epochs}")
        print(f"Train Loss: {train_losses[-1]:.4f} | Train Acc: {train_accuracies[-1]:.2f}%")
        print(f"Val Loss: {val_losses[-1]:.4f} | Val Acc: {val_accuracies[-1]:.2f}%")
        print(f"Precision: {precision_value:.4f} | Recall: {recall_value:.4f} | F1 Score: {f1_value:.4f}\n")

    return train_losses, val_losses, train_accuracies, val_accuracies, conf_matrix

# %%
t1 = time.time()
print(f"Using device: {device}")
train_losses, val_losses, train_accuracies, val_accuracies, conf_matrix = train_model(
    model, train_loader, val_loader, criterion, optimizer, num_epochs=50)

print("######## Training Finished in {} seconds ###########".format(time.time()-t1))
# Out:
# Using device: cuda
# Epoch 1/50
# Train Loss: 0.9365 | Train Acc: 69.49%
# Val Loss: 0.4851 | Val Acc: 83.33%
# Precision: 0.4167 | Recall: 0.5000 | F1 Score: 0.4545
#
# Epoch 2/50
# Train Loss: 1.2459 | Train Acc: 69.49%
# Val Loss: 0.4987 | Val Acc: 83.33%
# Precision: 0.4167 | Recall: 0.5000 | F1 Score: 0.4545
#
# Epoch 3/50
# Train Loss: 0.4938 | Train Acc: 77.97%
# Val Loss: 0.4581 | Val Acc: 83.33%
# Precision: 0.4167 | Recall: 0.5000 | F1 Score: 0.4545
#
# Epoch 4/50
# Train Loss: 0.4804 | Train Acc: 81.36%
# Val Loss: 0.6150 | Val Acc: 83.33%
# Precision: 0.4167 | Recall: 0.5000 | F1 Score: 0.4545
#
# Epoch 5/50
# Train Loss: 0.4283 | Train Acc: 82.20%
# Val Loss: 0.7223 | Val Acc: 83.33%
# Precision: 0.4167 | Recall: 0.5000 | F1 Score: 0.4545
#
# Epoch 6/50
# Train Loss: 0.4075 | Train Acc: 82.20%
# Val Loss: 0.9977 | Val Acc: 83.33%
# Precision: 0.4167 | Recall: 0.5000 | F1 Score: 0.4545
#
# Epoch 7/50
# Train Loss: 0.3836 | Train Acc: 82.20%
# Val Loss: 0.9264 | Val Acc: 83.33%
# Precision: 0.4167 | Recall: 0.5000 | F1 Score: 0.4545
#
# Epoch 8/50
# Train Loss: 0.4375 | Train Acc: 82.20%
# Val Loss: 0.5307 | Val Acc: 83.33%
# Precision: 0.4167 | Recall: 0.5000 | F1 Score: 0.4545
#
# Epoch 9/50
# Train Loss: 0.3743 | Train Acc: 82.20%
# Val Loss: 0.4346 | Val Acc: 83.33%
# Precision: 0.4167 | Recall: 0.5000 | F1 Score: 0.4545
#
# Epoch 10/50
# Train Loss: 0.3967 | Train Acc: 82.20%
# Val Loss: 0.4660 | Val Acc: 83.33%
# Precision: 0.4167 | Recall: 0.5000 | F1 Score: 0.4545
#
# Epoch 11/50
# Train Loss: 0.3695 | Train Acc: 83.05%
# Val Loss: 1.1131 | Val Acc: 83.33%
# Precision: 0.4167 | Recall: 0.5000 | F1 Score: 0.4545
#
# Epoch 12/50
# Train Loss: 0.3814 | Train Acc: 82.20%
# Val Loss: 1.3604 | Val Acc: 83.33%
# Precision: 0.4167 | Recall: 0.5000 | F1 Score: 0.4545
#
# Epoch 13/50
# Train Loss: 0.3707 | Train Acc: 79.66%
# Val Loss: 0.8714 | Val Acc: 80.00%
# Precision: 0.4138 | Recall: 0.4800 | F1 Score: 0.4444
#
# Epoch 14/50
# Train Loss: 0.3304 | Train Acc: 83.90%
# Val Loss: 0.6622 | Val Acc: 73.33%
# Precision: 0.4074 | Recall: 0.4400 | F1 Score: 0.4231
#
# Epoch 15/50
# Train Loss: 0.3013 | Train Acc: 86.44%
# Val Loss: 0.5109 | Val Acc: 83.33%
# Precision: 0.4167 | Recall: 0.5000 | F1 Score: 0.4545
#
# Epoch 16/50
# Train Loss: 0.2924 | Train Acc: 83.90%
# Val Loss: 0.5465 | Val Acc: 86.67%
# Precision: 0.9310 | Recall: 0.6000 | F1 Score: 0.6296
#
# Epoch 17/50
# Train Loss: 0.2350 | Train Acc: 88.14%
# Val Loss: 0.4806 | Val Acc: 83.33%
# Precision: 0.4167 | Recall: 0.5000 | F1 Score: 0.4545
#
# Epoch 18/50
# Train Loss: 0.2184 | Train Acc: 88.14%
# Val Loss: 1.1930 | Val Acc: 83.33%
# Precision: 0.4167 | Recall: 0.5000 | F1 Score: 0.4545
#
# Epoch 19/50
# Train Loss: 0.3783 | Train Acc: 80.51%
# Val Loss: 1.7549 | Val Acc: 23.33%
# Precision: 0.3580 | Recall: 0.3000 | F1 Score: 0.2256
#
# Epoch 20/50
# Train Loss: 0.3965 | Train Acc: 85.59%
# Val Loss: 5.4243 | Val Acc: 60.00%
# Precision: 0.3913 | Recall: 0.3600 | F1 Score: 0.3750
#
# Epoch 21/50
# Train Loss: 0.4217 | Train Acc: 82.20%
# Val Loss: 6.7115 | Val Acc: 56.67%
# Precision: 0.3864 | Recall: 0.3400 | F1 Score: 0.3617
#
# Epoch 22/50
# Train Loss: 0.3754 | Train Acc: 83.90%
# Val Loss: 2.0190 | Val Acc: 43.33%
# Precision: 0.3611 | Recall: 0.2600 | F1 Score: 0.3023
#
# Epoch 23/50
# Train Loss: 0.3491 | Train Acc: 83.90%
# Val Loss: 1.1474 | Val Acc: 50.00%
# Precision: 0.4777 | Recall: 0.4600 | F1 Score: 0.4223
#
# Epoch 24/50
# Train Loss: 0.3215 | Train Acc: 86.44%
# Val Loss: 0.6321 | Val Acc: 73.33%
# Precision: 0.4074 | Recall: 0.4400 | F1 Score: 0.4231
#
# Epoch 25/50
# Train Loss: 0.3223 | Train Acc: 84.75%
# Val Loss: 0.9486 | Val Acc: 83.33%
# Precision: 0.4167 | Recall: 0.5000 | F1 Score: 0.4545
#
# Epoch 26/50
# Train Loss: 0.2748 | Train Acc: 88.14%
# Val Loss: 0.9219 | Val Acc: 50.00%
# Precision: 0.3750 | Recall: 0.3000 | F1 Score: 0.3333
#
# Epoch 27/50
# Train Loss: 0.2631 | Train Acc: 88.14%
# Val Loss: 0.8906 | Val Acc: 83.33%
# Precision: 0.4167 | Recall: 0.5000 | F1 Score: 0.4545
#
# Epoch 28/50
# Train Loss: 0.2333 | Train Acc: 89.83%
# Val Loss: 0.6709 | Val Acc: 70.00%
# Precision: 0.5000 | Recall: 0.5000 | F1 Score: 0.4991
#
# Epoch 29/50
# Train Loss: 0.2736 | Train Acc: 87.29%
# Val Loss: 0.9188 | Val Acc: 50.00%
# Precision: 0.4777 | Recall: 0.4600 | F1 Score: 0.4223
#
# Epoch 30/50
# Train Loss: 0.2666 | Train Acc: 83.90%
# Val Loss: 5.7638 | Val Acc: 16.67%
# Precision: 0.0833 | Recall: 0.5000 | F1 Score: 0.1429
#
# Epoch 31/50
# Train Loss: 0.2165 | Train Acc: 88.98%
# Val Loss: 3.9609 | Val Acc: 20.00%
# Precision: 0.5862 | Recall: 0.5200 | F1 Score: 0.1855
#
# Epoch 32/50
# Train Loss: 0.1855 | Train Acc: 93.22%
# Val Loss: 4.1012 | Val Acc: 16.67%
# Precision: 0.0833 | Recall: 0.5000 | F1 Score: 0.1429
#
# Epoch 33/50
# Train Loss: 0.1313 | Train Acc: 95.76%
# Val Loss: 5.7771 | Val Acc: 16.67%
# Precision: 0.0833 | Recall: 0.5000 | F1 Score: 0.1429
#
# Epoch 34/50
# Train Loss: 0.1617 | Train Acc: 94.07%
# Val Loss: 4.7881 | Val Acc: 26.67%
# Precision: 0.5926 | Recall: 0.5600 | F1 Score: 0.2634
#
# Epoch 35/50
# Train Loss: 0.2757 | Train Acc: 93.22%
# Val Loss: 1.6112 | Val Acc: 56.67%
# Precision: 0.4500 | Recall: 0.4200 | F1 Score: 0.4222
#
# Epoch 36/50
# Train Loss: 0.2883 | Train Acc: 88.14%
# Val Loss: 9.6917 | Val Acc: 16.67%
# Precision: 0.0833 | Recall: 0.5000 | F1 Score: 0.1429
#
# Epoch 37/50
# Train Loss: 0.5169 | Train Acc: 87.29%
# Val Loss: 1.2522 | Val Acc: 70.00%
# Precision: 0.5000 | Recall: 0.5000 | F1 Score: 0.4991
#
# Epoch 38/50
# Train Loss: 0.2426 | Train Acc: 88.98%
# Val Loss: 5.6049 | Val Acc: 20.00%
# Precision: 0.5862 | Recall: 0.5200 | F1 Score: 0.1855
#
# Epoch 39/50
# Train Loss: 0.2601 | Train Acc: 89.83%
# Val Loss: 6.1480 | Val Acc: 16.67%
# Precision: 0.0833 | Recall: 0.5000 | F1 Score: 0.1429
#
# Epoch 40/50
# Train Loss: 0.1903 | Train Acc: 91.53%
# Val Loss: 1.5016 | Val Acc: 40.00%
# Precision: 0.5397 | Recall: 0.5600 | F1 Score: 0.3891
#
# Epoch 41/50
# Train Loss: 0.1172 | Train Acc: 95.76%
# Val Loss: 1.1093 | Val Acc: 56.67%
# Precision: 0.5446 | Recall: 0.5800 | F1 Score: 0.4994
#
# Epoch 42/50
# Train Loss: 0.0664 | Train Acc: 99.15%
# Val Loss: 1.9125 | Val Acc: 83.33%
# Precision: 0.4167 | Recall: 0.5000 | F1 Score: 0.4545
#
# Epoch 43/50
# Train Loss: 0.0584 | Train Acc: 97.46%
# Val Loss: 2.2186 | Val Acc: 83.33%
# Precision: 0.4167 | Recall: 0.5000 | F1 Score: 0.4545
#
# Epoch 44/50
# Train Loss: 0.0548 | Train Acc: 99.15%
# Val Loss: 1.9968 | Val Acc: 80.00%
# Precision: 0.5926 | Recall: 0.5600 | F1 Score: 0.5673
#
# Epoch 45/50
# Train Loss: 0.0608 | Train Acc: 97.46%
# Val Loss: 2.4466 | Val Acc: 83.33%
# Precision: 0.4167 | Recall: 0.5000 | F1 Score: 0.4545
#
# Epoch 46/50
# Train Loss: 0.3981 | Train Acc: 91.53%
# Val Loss: 4.4489 | Val Acc: 36.67%
# Precision: 0.5284 | Recall: 0.5400 | F1 Score: 0.3603
#
# Epoch 47/50
# Train Loss: 0.1958 | Train Acc: 89.83%
# Val Loss: 4.0279 | Val Acc: 60.00%
# Precision: 0.5120 | Recall: 0.5200 | F1 Score: 0.4886
#
# Epoch 48/50
# Train Loss: 0.1721 | Train Acc: 88.98%
# Val Loss: 3.9726 | Val Acc: 63.33%
# Precision: 0.4716 | Recall: 0.4600 | F1 Score: 0.4599
#
# Epoch 49/50
# Train Loss: 0.1331 | Train Acc: 93.22%
# Val Loss: 3.1356 | Val Acc: 76.67%
# Precision: 0.4107 | Recall: 0.4600 | F1 Score: 0.4340
#
# Epoch 50/50
# Train Loss: 0.1223 | Train Acc: 95.76%
# Val Loss: 2.0981 | Val Acc: 60.00%
# Precision: 0.4603 | Recall: 0.4400 | F1 Score: 0.4410
#
# ######## Training Finished in 364.7769196033478 seconds ###########

# %% [markdown]
# # Evaluating

# %%
model.eval() 

with torch.no_grad(): 
    correct = 0
    total = 0
    for data in test_loader:
        images, labels = data[0].to(device), data[1].to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
    print(f'Test Accuracy of the model on the {total} test images: {(correct / total) * 100:.2f}%')
# Out:
# Test Accuracy of the model on the 52 test images: 73.08%

# %%
def plot_training(train_losses, val_losses, train_accuracies, val_accuracies):
    epochs = range(1, len(train_losses) + 1)

    plt.figure(figsize=(12, 5))
    
    # Plot loss
    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, label='Train Loss')
    plt.plot(epochs, val_losses, label='Val Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss')
    plt.legend()

    # Plot accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_accuracies, label='Train Accuracy')
    plt.plot(epochs, val_accuracies, label='Val Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy (%)')
    plt.title('Training and Validation Accuracy')
    plt.legend()

    plt.show()

plot_training(train_losses, val_losses, train_accuracies, val_accuracies)

# %%
cm = conf_matrix.cpu().numpy()
disp = ConfusionMatrixDisplay(cm, display_labels=classes,)
disp.plot()

# %% [markdown]
# # Metrics

# %%
precision = MulticlassPrecision(num_classes=num_classes, average=None)
recall = MulticlassRecall(num_classes=num_classes, average=None)
f1_score = MulticlassF1Score(num_classes=num_classes, average=None)


all_preds = []
all_labels = []

model.eval()
with torch.no_grad():
    for inputs, labels in val_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        all_preds.append(preds.cpu())
        all_labels.append(labels.cpu())


all_preds = torch.cat(all_preds)
all_labels = torch.cat(all_labels)


per_class_precision = precision(all_preds, all_labels)
per_class_recall = recall(all_preds, all_labels)
per_class_f1 = f1_score(all_preds, all_labels)


for i, name in enumerate(classes):
    print(f"Class {i}-{name}: Precision: {per_class_precision[i]:.2f}, Recall: {per_class_recall[i]:.2f}, F1-Score: {per_class_f1[i]:.2f}")
# Out:
# Class 0-cancer: Precision: 0.11, Recall: 0.20, F1-Score: 0.14
# Class 1-non-cancer: Precision: 0.81, Recall: 0.68, F1-Score: 0.74

# %% [markdown]
# # Save Model

# %%
# torch.save(model.state_dict(), '/home/viviane/projects/breast-cancer-v2/models/model_alexnet.pt')
